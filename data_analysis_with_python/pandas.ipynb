# %%
import pandas as pd

# %%
data = [1, 2, 3, 4, 5]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data = [1, 2, 3, 4, 5]
index = ['a', 'b', 'c', 'd', 'e']
series_with_index = pd.Series(data, index=index)
print(series_with_index)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
df = pd.read_csv('data.csv')
print(df.head())
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
new_df = df['Category']
new_df.head()
# Out:
# 0    A
# 1    B
# 2    C
# 3    B
# 4    B
# Name: Category, dtype: object

# %%
l_df = df.loc[0]
l_df
# Out:
# Date        2023-01-01
# Category             A
# Value             28.0
# Product       Product1
# Sales            754.0
# Region            East
# Name: 0, dtype: object

# %%
i_df = df.iloc[0]
i_df
# Out:
# Date        2023-01-01
# Category             A
# Value             28.0
# Product       Product1
# Sales            754.0
# Region            East
# Name: 0, dtype: object

# %%
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.at[2, 'Sales']
# Out:
# np.float64(398.0)

# %%
df.iat[2, 4]
# Out:
# np.float64(398.0)

# %%
#data manupulation with pandas
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
#add a column 'Discounted_Price' which is 10% less than 'Price'
df['Discounted_Price'] = df['Sales'] * 0.9

df.head()
# Out:
#          Date Category  Value   Product  Sales Region  Discounted_Price
# 0  2023-01-01        A   28.0  Product1  754.0   East             678.6
# 1  2023-01-02        B   39.0  Product3  110.0  North              99.0
# 2  2023-01-03        C   32.0  Product2  398.0   East             358.2
# 3  2023-01-04        B    8.0  Product1  522.0   East             469.8
# 4  2023-01-05        B   26.0  Product3  869.0  North             782.1

# %%
#remove column 'Discounted_Price'
df.drop('Discounted_Price', axis=1, inplace=True)
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000
