# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title('scatter plot for Total Bill vs Tip')
plt.show()

# %%
sns.lineplot(x='size', y='total_bill', data=tips)
plt.title('Line plot of Totall Bills by size')
plt.show()

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.title('Bar Plot of Total Bill by Day')
plt.show()

# %%
#box plot
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('BoxPlot of total bill by day')
plt.show()

# %%
#violinplot
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title('Violin plot of Total Bill by Day')
plt.show()

# %%
#Histogram
sns.histplot(tips['total_bill'], bins=10, kde=True)
plt.title("Hisplot By Total Bill")
# Out:
# Text(0.5, 1.0, 'Hisplot By Total Bill')

# %%
sns.kdeplot(tips['total_bill'], fill=True)
plt.show()

# %%
#pairplot
sns.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#corelation
corr = tips[['total_bill', 'tip', 'size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df = pd.read_csv('data_files/data.csv')
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Value', data=df, estimator=sum)
plt.title('Bar Plot of Value by Category')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Sales', data=df, estimator=sum)
plt.title('Bar Plot of Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()

# %%
df = sns.load_dataset('tips')
sns.set(style="whitegrid")
sns.set_context("notebook")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df, x="total_bill", y="tip", hue="smoker", style="smoker")
plt.title('Total bill vs Tip by Smoker')
# Out:
# Text(0.5, 1.0, 'Total bill vs Tip by Smoker')

# %%
df = pd.read_csv('data_files/dm_office_sales.csv')
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.scatterplot(data = df, x = 'salary', y='sales', hue = 'level of education')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(12,4), dpi=300)
sns.scatterplot(data = df, x = 'salary', y='sales', hue = 'level of education')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# plt.figure(figsize=(12,4), dpi=300)
sns.scatterplot(data = df, x = 'salary', y='sales', hue = 'level of education', palette = "bright")
plt.title('Salary vs Sales')
plt.xlabel('Salary')
plt.ylabel('Sales')
plt.show()

# %%
df_1 = pd.read_csv('data_files/dm_office_sales.csv')
df_2 = sns.load_dataset('tips')

# %%
df_1.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
#rugplot
sns.rugplot(data=df_1, x='salary', height=0.75, color='b')
# Out:
# <Axes: xlabel='salary'>

# %%
#rugplot
sns.rugplot(data=df_2, x='total_bill', height=0.75, color='b')
# Out:
# <Axes: xlabel='total_bill'>

# %%
df_1.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
figu =plt.figure(figsize=(10,10))
sns.displot(data=df_1, x="salary", hue="division", color='green', kde=True, bins=20)
plt.show()

# %%
sns.displot(data=df_2, x="total_bill", bins=20, color="orange")

# %%
#histplot
sns.histplot(data=df_1, x="salary", hue="training level", multiple="stack", binwidth=1000, lw=0.5)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
#histplot
sns.histplot(data=df_2, x="total_bill", multiple="stack", color='r', edgecolor="black", linewidth=0.5, kde=True, bins=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(df_2['total_bill'], fill=True, color='b', label='Total Bill', alpha=0.5)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df_2['total_bill'], fill=True, color='b', label='Total Bill', alpha=0.5, bw_adjust=0.1)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df_2['total_bill'], color='b', label='Total Bill', alpha=0.5, clip=(10, 40))
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.jointplot(data=df_2, x="total_bill", y="tip", kind="reg")
