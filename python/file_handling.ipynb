# %%
with open("example.txt", 'r') as file:
    content = file.read()
    print(content)
# Out:
# hello world. How are you doing today?
# "Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you with anything you need. How about you? How are you doing today?"

# %%
with open("example.txt", 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# hello world. How are you doing today?
# "Hello! I'm just a computer program,
# so I don't have feelings, but I'm here and ready to help you with anything you need. How about you? How are you doing today?"

# %%
with open("output.txt", 'w') as file:
    file.write("Hello, World!")
    file.write("\nThis is a new line.")

# %%
with open("output.txt", 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, World!
# This is a new line.

# %%
new_directroy = "data_files"
import os
if not os.path.exists(new_directroy):
    os.makedirs(new_directroy)
    print(f"Directory '{new_directroy}' created.")
else:
    print(f"Directory '{new_directroy}' already exists.")
# Out:
# Directory 'data_files' already exists.

# %%
##listing files in a directory
files = os.listdir(".")
print("Files in current directory:", files)
# Out:
# Files in current directory: ['conditional_statement.ipynb', 'data_files', 'example.txt', 'file_handling.ipynb', 'filter_function.ipynb', 'function.ipynb', 'lambda_function.ipynb', 'loops.ipynb', 'map_function.ipynb', 'operator.ipynb', 'output.txt']

# %%
dir_name = "data_files"
file_name = "sample.txt"
full_path = os.path.join(dir_name, file_name)
print("Full file path:", full_path)
# Out:
# Full file path: data_files\sample.txt

# %%
dir_name = "data_files"
file_name = "sample.txt"
full_path = os.path.join(os.getcwd(), dir_name, file_name)
print("Full file path:", full_path)
# Out:
# Full file path: f:\Practice\2025\December\Data-Analysis-A-Z\python\data_files\sample.txt
