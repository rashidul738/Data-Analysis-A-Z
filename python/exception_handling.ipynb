# %%
try:
    a = b
except NameError as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: name 'b' is not defined

# %%
result = 8/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 result = 8/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 8/0
except ZeroDivisionError as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: division by zero

# %%
try:
    result = 8/0
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: division by zero

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("Invalid input! Please enter a valid integer.")
except ZeroDivisionError:
    
    print("Error! Please enter number greater than zero.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
else:
    print(f"The result is: {result}")
finally:
    print("Execution completed.")
# Out:
# Error! Please enter number greater than zero.
# Execution completed.

# %%
try:
    file = open("non_existent_file.txt", "r")
    content = file.read()
    a = b
except FileNotFoundError as e:
    print(f"File doesn't exists: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
finally:
    if 'file' in locals() and not file.closed:  
        file.close('file closed')
# Out:
# File doesn't exists: [Errno 2] No such file or directory: 'non_existent_file.txt'
