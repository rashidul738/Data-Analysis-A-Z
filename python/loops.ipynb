# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 5, 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(5, 1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
str = "Hello, World!"
for char in str:
    print(char)
# Out:
# H
# e
# l
# l
# o
# ,
#
# W
# o
# r
# l
# d
# !

# %%
count = 0
while count < 5:
    print("Count:", count)
    count += 1
# Out:
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4

# %%
for i in range(10):
    if i== 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(5):
    if i == 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    if i == 3 or i == 7:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 6
# 8
# 9

# %%
n = 10
sum = 0
count = 1
while count <= n:
    sum = sum+count
    print("Intermediate sum after adding", count, "is", sum)
    count = count+1
print("The sum is:", sum)
# Out:
# Intermediate sum after adding 1 is 1
# Intermediate sum after adding 2 is 3
# Intermediate sum after adding 3 is 6
# Intermediate sum after adding 4 is 10
# Intermediate sum after adding 5 is 15
# Intermediate sum after adding 6 is 21
# Intermediate sum after adding 7 is 28
# Intermediate sum after adding 8 is 36
# Intermediate sum after adding 9 is 45
# Intermediate sum after adding 10 is 55
# The sum is: 55
